# %% [markdown]
# # This is a test!
# Testing testing...
#
# ## Image test
# <img src="https://live.staticflickr.com/65535/50065947228_dd66823abe_3k.jpg" alt="rocket!!" width="600"/>

# %%
# Dependencies
import numpy as np
from matplotlib import pyplot as plt

# %%
# Test numpy and matplotlib
t = np.arange(0.0, 5.0, 0.05)
plt.plot(t, np.sin(np.pi*t))
